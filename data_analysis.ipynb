# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Este ficheiro permite perceber a complexidade do dataset (numeros de classes, amostras, existencia de valores nulos)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os

# %% [markdown]
# ### Overview

# %%
# Função para obter as estatísticas de cada dataset
def obter_estatisticas(dataset_path):
    # Carregar o dataset
    df = pd.read_csv(dataset_path)
    
    # Definir a última coluna como coluna alvo
    target_column = df.columns[-1]
    
    # Contar número de linhas e colunas
    num_linhas, num_colunas = df.shape
    
    # Verificar as classes e a classe majoritária
    classes = df[target_column].value_counts()
    num_classes = len(classes)
    classe_majoritaria_percentual = (classes.max() / num_linhas) * 100
    
    # Verificar valores nulos
    nulos = df.isnull().any().any()
    
    return {
        'Dataset': os.path.basename(dataset_path),
        'N amostras': num_linhas,
        'N features': num_colunas - 1,  # Subtrai a coluna alvo
        'N classes': num_classes,
        'Classe majoritária (%)': f"{classe_majoritaria_percentual:.1f}%",
        'Nulos?': 'Sim' if nulos else 'Não'
    }

# %%
# Função para gerar gráficos simples da distribuição das classes
def gerar_grafico_distribuicao(df):
    # Definir a última coluna como coluna alvo
    target_column = df.columns[-1]
    
    # Gerar gráfico de barras para a distribuição das classes
    classes = df[target_column].value_counts()
    classes.plot(kind='bar', color='skyblue')
    plt.title(f'Distribuição das classes - {target_column}')
    plt.xlabel('Classe')
    plt.ylabel('Contagem')
    plt.show()

# %%
# Função para gerar a matriz de correlação e gráfico de calor
def gerar_matriz_correlacao(df):
    # Calcular a matriz de correlação
    corr_matrix = df.corr()
    
    # Gerar o gráfico de calor (heatmap)
    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
    plt.title('Matriz de Correlação')
    plt.show()

# %%
# Caminho para a pasta de datasets
pasta_datasets = 'class_imbalance/'

# %%
estatisticas = []
for filename in os.listdir(pasta_datasets):
    if filename.endswith('.csv'):
        dataset_path = os.path.join(pasta_datasets, filename)
        
        try:
            # Obter as estatísticas do dataset
            stats = obter_estatisticas(dataset_path)
            estatisticas.append(stats)
            
            # Carregar o dataset
            df = pd.read_csv(dataset_path)
            target_column = df.columns[-1]
            X = df.drop(columns=[target_column])
            y = df[target_column]

            # Filtrar apenas colunas numéricas para correlação
            X_numericas = X.select_dtypes(include=[np.number])
            
            # Criar figura com 2 subplots lado a lado
            fig, axes = plt.subplots(1, 2, figsize=(16, 6))

            # Gráfico de distribuição das classes
            class_counts = y.value_counts()
            class_counts.plot(kind='bar', ax=axes[0], color='skyblue')
            axes[0].set_title(f'Distribuição das Classes - {filename}')
            axes[0].set_xlabel('Classe')
            axes[0].set_ylabel('Contagem')

            # Matriz de correlação apenas se houver colunas numéricas
            if not X_numericas.empty:
                corr = X_numericas.corr()
                sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f',
                            linewidths=0.5, ax=axes[1])
                axes[1].set_title('Matriz de Correlação')
            else:
                axes[1].axis('off')
                axes[1].text(0.5, 0.5, 'Sem colunas numéricas',
                             ha='center', va='center', fontsize=12)

            plt.tight_layout()
            plt.show()
        
        except Exception as e:
            print(f"Erro ao processar o dataset {filename}: {e}")

# %%
# Criar um DataFrame com as estatísticas coletadas
tabela_overview = pd.DataFrame(estatisticas).drop_duplicates(subset='Dataset')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Criar um DataFrame com as estatísticas coletadas
# ----> 2 tabela_overview = pd.DataFrame(estatisticas).drop_duplicates(subset='Dataset')
#
# NameError: name 'pd' is not defined

# %%
# Mostrar todas as colunas e linhas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Exibir a tabela completa
tabela_overview
# Out:
#                                     Dataset  N amostras  N features  \
# 0              dataset_1000_hypothyroid.csv        3772          29
# 1        dataset_1002_ipums_la_98-small.csv        7485          55
# 2        dataset_1004_synthetic_control.csv         600          60
# 3   dataset_1013_analcatdata_challenger.csv         138           2
# 4         dataset_1014_analcatdata_dmft.csv         797           4
# 5                    dataset_1016_vowel.csv         990          12
# 6        dataset_1018_ipums_la_99-small.csv        8844          56
# 7           dataset_1020_mfeat-karhunen.csv        2000          64
# 8              dataset_1021_page-blocks.csv        5473          10
# 9              dataset_1022_mfeat-pixel.csv        2000         240
# 10                 dataset_1023_soybean.csv         683          35
# 11           dataset_1039_hiva_agnostic.csv        4229        1617
# 12                dataset_1045_kc1-top5.csv         145          94
# 13                     dataset_1049_pc4.csv        1458          37
# 14                     dataset_1050_pc3.csv        1563          37
# 15                     dataset_1056_mc1.csv        9466          38
# 16                     dataset_1059_ar1.csv         121          29
# 17                     dataset_1061_ar4.csv         107          29
# 18                     dataset_1064_ar6.csv         101          29
# 19                     dataset_1065_kc3.csv         458          39
# 20                dataset_311_oil_spill.csv         937          49
# 21                    dataset_312_scene.csv        2407         299
# 22                dataset_316_yeast_ml8.csv        2417         116
# 23                      dataset_38_sick.csv        3772          29
# 24      dataset_450_analcatdata_lawsuit.csv         264           4
# 25                 dataset_463_backache.csv         180          31
# 26                     dataset_757_meta.csv         528          21
# 27       dataset_764_analcatdata_apnea3.csv         450           3
# 28       dataset_765_analcatdata_apnea2.csv         475           3
# 29       dataset_767_analcatdata_apnea1.csv         475           3
# 30      dataset_865_analcatdata_neavote.csv         100           2
# 31    dataset_867_visualizing_livestock.csv         130           2
# 32    dataset_875_analcatdata_chlamydia.csv         100           3
# 33          dataset_940_water-treatment.csv         527          36
# 34     dataset_947_arsenic-male-bladder.csv         559           4
# 35   dataset_949_arsenic-female-bladder.csv         559           4
# 36      dataset_950_arsenic-female-lung.csv         559           4
# 37        dataset_951_arsenic-male-lung.csv         559           4
# 38             dataset_954_spectrometer.csv         531         101
# 39                  dataset_958_segment.csv        2310          19
# 40      dataset_962_mfeat-morphological.csv        2000           6
# 41   dataset_966_analcatdata_halloffame.csv        1340          16
# 42     dataset_968_analcatdata_birthday.csv         365           3
# 43            dataset_971_mfeat-fourier.csv        2000          76
# 44           dataset_976_JapaneseVowels.csv        9961          14
# 45            dataset_978_mfeat-factors.csv        2000         216
# 46                dataset_980_optdigits.csv        5620          64
# 47        dataset_984_analcatdata_draft.csv         366           4
# 48                  dataset_987_collins.csv         500          22
# 49            dataset_995_mfeat-zernike.csv        2000          47
#
#     N classes Classe majoritária (%) Nulos?
# 0           2                  92.3%    Sim
# 1           2                  89.4%    Sim
# 2           2                  83.3%    Não
# 3           2                  93.5%    Não
# 4           2                  80.6%    Não
# 5           2                  90.9%    Não
# 6           2                  93.6%    Sim
# 7           2                  90.0%    Não
# 8           2                  89.8%    Não
# 9           2                  90.0%    Não
# 10          2                  86.5%    Sim
# 11          2                  96.5%    Não
# 12          2                  94.5%    Não
# 13          2                  87.8%    Não
# 14          2                  89.8%    Não
# 15          2                  99.3%    Não
# 16          2                  92.6%    Não
# 17          2                  81.3%    Não
# 18          2                  85.1%    Não
# 19          2                  90.6%    Não
# 20          2                  95.6%    Não
# 21          2                  82.1%    Não
# 22          2                  98.6%    Não
# 23          2                  93.9%    Sim
# 24          2                  92.8%    Não
# 25          2                  86.1%    Não
# 26          2                  89.8%    Sim
# 27          2                  87.8%    Não
# 28          2                  86.5%    Não
# 29          2                  87.2%    Não
# 30          2                  93.0%    Não
# 31          2                  80.8%    Não
# 32          2                  81.0%    Não
# 33          2                  84.8%    Sim
# 34          2                  95.7%    Não
# 35          2                  85.7%    Não
# 36          2                  96.6%    Não
# 37          2                  97.7%    Não
# 38          2                  89.6%    Não
# 39          2                  85.7%    Não
# 40          2                  90.0%    Não
# 41          2                  90.7%    Sim
# 42          2                  85.5%    Sim
# 43          2                  90.0%    Não
# 44          2                  83.8%    Não
# 45          2                  90.0%    Não
# 46          2                  89.8%    Não
# 47          2                  91.3%    Sim
# 48          2                  84.0%    Não
# 49          2                  90.0%    Não
